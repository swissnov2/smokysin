# %%
import os 
print(os.getcwd())
# Out:
# F:\projects\healtcare-ai

# %%
print(os.listdir())
# Out:
# ['.gitignore', '.ipynb_checkpoints', 'apps', 'cardio_prediction.ipynb', 'data', 'models', 'notebook', 'outputs', 'README.md', 'requirements.txt', 'train_model.py', 'Untitled.ipynb']

# %%
print(os.listdir("data"))
# Out:
# ['sample_medical_examination.csv']

# %%
import pandas as pd
df = pd.read_csv("data/sample_medical_examination.csv")
df.head()
# Out:
#    PatientID  Age Gender  Height  Weight   BMI BloodPressure  Cholesterol  \
# 0          1   34      M     175      78  25.5        120/80            1
# 1          2   45      F     162      68  26.0        130/85            2
# 2          3   29      M     180      90  27.8        140/90            1
# 3          4   52      F     158      72  28.8        150/95            3
# 4          5   38      M     170      80  27.7        125/82            2
#
#    Diabetes  cardio
# 0         0       0
# 1         1       1
# 2         0       0
# 3         1       1
# 4         0       0

# %%
import pandas as pd
df = pd.read_csv("data/sample_medical_examination.csv")
df.head()
# Out:
#    PatientID  Age Gender  Height  Weight   BMI BloodPressure  Cholesterol  \
# 0          1   34      M     175      78  25.5        120/80            1
# 1          2   45      F     162      68  26.0        130/85            2
# 2          3   29      M     180      90  27.8        140/90            1
# 3          4   52      F     158      72  28.8        150/95            3
# 4          5   38      M     170      80  27.7        125/82            2
#
#    Diabetes  cardio
# 0         0       0
# 1         1       1
# 2         0       0
# 3         1       1
# 4         0       0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PatientID      10 non-null     int64
#  1   Age            10 non-null     int64
#  2   Gender         10 non-null     str
#  3   Height         10 non-null     int64
#  4   Weight         10 non-null     int64
#  5   BMI            10 non-null     float64
#  6   BloodPressure  10 non-null     str
#  7   Cholesterol    10 non-null     int64
#  8   Diabetes       10 non-null     int64
#  9   cardio         10 non-null     int64
# dtypes: float64(1), int64(7), str(2)
# memory usage: 932.0 bytes

# %%
df.isnull().sum()
# Out:
# PatientID        0
# Age              0
# Gender           0
# Height           0
# Weight           0
# BMI              0
# BloodPressure    0
# Cholesterol      0
# Diabetes         0
# cardio           0
# dtype: int64

# %%
df.describe()
# Out:
#        PatientID        Age      Height     Weight        BMI  Cholesterol  \
# count   10.00000  10.000000   10.000000  10.000000  10.000000    10.000000
# mean     5.50000  40.400000  169.600000  76.300000  26.440000     1.800000
# std      3.02765   9.143304    8.435375  11.304375   2.350508     0.788811
# min      1.00000  29.000000  158.000000  60.000000  21.300000     1.000000
# 25%      3.25000  33.250000  162.750000  68.500000  25.625000     1.000000
# 50%      5.50000  39.500000  169.000000  75.000000  27.350000     2.000000
# 75%      7.75000  46.500000  175.750000  83.750000  27.775000     2.000000
# max     10.00000  55.000000  182.000000  95.000000  28.800000     3.000000
#
#         Diabetes     cardio
# count  10.000000  10.000000
# mean    0.400000   0.400000
# std     0.516398   0.516398
# min     0.000000   0.000000
# 25%     0.000000   0.000000
# 50%     0.000000   0.000000
# 75%     1.000000   1.000000
# max     1.000000   1.000000

# %%
df["Gender"].value_counts()
# Out:
# Gender
# M    5
# F    5
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
df["Gender"].value_counts().plot(kind="bar")

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")

plt.show()

# %%
df["Diabetes"].value_counts()
# Out:
# Diabetes
# 0    6
# 1    4
# Name: count, dtype: int64

# %%
df["Diabetes"].value_counts()
plt.title("Cardivascular Disease Cases")
plt.xlabel("Caedio (0=No, 1=Yes)")
plt.ylabel("Number of Patients")

plt.show()

# %%
df.groupby("Gender")["BMI"].mean()
# Out:
# Gender
# F    25.46
# M    27.42
# Name: BMI, dtype: float64
