# %%
import os
os.listdir("F:/Datasets/Population")
# Out:
# []

# %%
import pandas as pd
df = pd.read_csv("F:/population.csv")
df.head()
# Out:
#          Series Name  Series Code         Country Name Country Code  \
# 0  Population, total  SP.POP.TOTL  Antigua and Barbuda          ATG
# 1  Population, total  SP.POP.TOTL            Argentina          ARG
# 2  Population, total  SP.POP.TOTL                Aruba          ABW
# 3  Population, total  SP.POP.TOTL         Bahamas, The          BHS
# 4  Population, total  SP.POP.TOTL             Barbados          BRB
#
#    2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]  \
# 0        88028.0        89253.0        90409.0        91516.0        92562.0
# 1     40788453.0     41261490.0     41733271.0     42202935.0     42669500.0
# 2       101669.0       102046.0       102560.0       103159.0       103774.0
# 3       354942.0       359577.0       363584.0       367168.0       370633.0
# 4       282131.0       282987.0       283700.0       284296.0       284825.0
#
#    2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  \
# ...
